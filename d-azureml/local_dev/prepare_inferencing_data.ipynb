# %% [markdown]
# # Interactive notebook used to prepare code parts for Azure ML

# %% [markdown]
# ### Load data

# %%
import pandas as pd
import numpy as np

# %%
# Load raw data
df = pd.read_csv("../data/lending_club.csv")

df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# ...

# %% [markdown]
# ### Prepare data

# %%
# Get random 10 rows
df = df.sample(10)
df
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 6578      20000.0   60 months     16.55       492.23     D        D2
# 159904    35000.0   36 months     14.47      1204.23     C        C2
# 165022    33025.0   36 months     18.25      1198.08     E        E1
# 36585     28000.0   36 months     18.49      1019.17     D        D2
# 279894     1800.0   36 months     10.49        58.50     B        B3
# 388719    13000.0   36 months     14.99       450.59     C        C5
# 296240     5000.0   36 months      7.89       156.43     A        A5
# 100914    17325.0   36 months     12.49       579.51     B        B5
# 3502       4000.0   36 months     12.74       134.28     C        C1
# 66205     12225.0   60 months     20.99       330.66     E        E5
#
#                     emp_title emp_length home_ownership  annual_inc  ...  \
# 6578           letter carrier  10+ years           RENT     59000.0  ...
# ...

# %%
# Generate some changes to simulate new data
df['loan_amnt'].iloc[0] = 25000
df['loan_amnt'].iloc[3] = 35000
df['int_rate'].iloc[1] = 16.11
df['int_rate'].iloc[2] = 16.11
df['home_ownership'].iloc[4] = "RENT"
df['home_ownership'].iloc[5] = "RENT"
df['home_ownership'].iloc[6] = "RENT"
df['emp_length'].iloc[7] = "9 years"
df['emp_length'].iloc[8] = "9 years"
df['emp_length'].iloc[9] = "9 years"
df = df.drop('loan_status', axis=1)
df
# Out:
# C:\Users\tokubica\AppData\Local\Temp\ipykernel_13764\4262237648.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loan_amnt'].iloc[0] = 25000
# C:\Users\tokubica\AppData\Local\Temp\ipykernel_13764\4262237648.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loan_amnt'].iloc[3] = 35000
# C:\Users\tokubica\AppData\Local\Temp\ipykernel_13764\4262237648.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Save preprocessed data for use with AutoML before making OHE
df.to_csv("../data/lending_club_inferencing.csv", index=False)

# %% [markdown]
# # RAG demo level 3

# %%
questions = [
    "What movies are about Abby?",
    "I have seen all Star Wars movies and would like tips for something similar I can watch next.",
    "What is the most common genre of the movies where one of key figures is called Mark?",
    "Are there any movies where Prague takes major role and present city as mysterious and ancient?",
    "When movies about drugs are concerned, is it usually rather serious or funny?",
    "What are some movies featuring a strong female lead that also involve adventure?",
    "Which Western films feature outlaws riding to their doom in the American Southwest?"
]

# %%
import subprocess
import os
import json

original_dir = os.getcwd()
try:
    # Jump into the terraform directory
    os.chdir('terraform')

    # Get the database connection string
    PGHOST = subprocess.run(['terraform', 'output', '-raw', 'PGHOST'], stdout=subprocess.PIPE).stdout.decode('utf-8')
    PGDATABASE = subprocess.run(['terraform', 'output', '-raw', 'PGDATABASE'], stdout=subprocess.PIPE).stdout.decode('utf-8')
    PGUSER = subprocess.run(['terraform', 'output', '-raw', 'PGUSER'], stdout=subprocess.PIPE).stdout.decode('utf-8')
    PGPASSWORD = subprocess.run(['terraform', 'output', '-raw', 'PGPASSWORD'], stdout=subprocess.PIPE).stdout.decode('utf-8')
    db_uri = f"postgresql://{PGUSER}:{PGPASSWORD}@{PGHOST}/{PGDATABASE}?sslmode=require"

    # Get the embedding model endpoint and key
    model_configurations = subprocess.run(['terraform', 'output', '-raw', 'model_configurations'], stdout=subprocess.PIPE).stdout.decode('utf-8')
    model_config = json.loads(model_configurations)
    embedding_model = model_config["models"]["text-embedding-3-large"]
    EMBEDDINGS_ENDPOINT = embedding_model["endpoint"]
    EMBEDDINGS_KEY = embedding_model["key"]
    gpt_4o_mini_model = model_config["models"]["gpt-4o-mini"]
    GPT_4O_MINI_ENDPOINT = gpt_4o_mini_model["endpoint"]
    GPT_4O_MINI_KEY = gpt_4o_mini_model["key"]
    gpt_4o_model = model_config["models"]["gpt-4o"]
    GPT_4O_ENDPOINT = gpt_4o_model["endpoint"]
    GPT_4O_KEY = gpt_4o_model["key"]

    print(f"Using {db_uri} as the database connection string")
    print(f"Using {EMBEDDINGS_ENDPOINT} as the embedding model endpoint")
    print(f"Using {GPT_4O_MINI_ENDPOINT} as the gpt-4o-mini model endpoint")
    print(f"Using {GPT_4O_ENDPOINT} as the gpt-4o model endpoint")

finally:
    os.chdir(original_dir)
# Out:
# Using postgresql://psqladmin:)ycxlsxlLRKks*g#@psql-graphrag-psbv.postgres.database.azure.com/demo?sslmode=require as the database connection string
# Using https://graphrag-psbv.openai.azure.com/ as the embedding model endpoint
# Using https://graphrag-psbv.openai.azure.com/ as the gpt-4o-mini model endpoint
# Using https://graphrag-psbv.openai.azure.com/ as the gpt-4o model endpoint

# %%
import psycopg2
from psycopg2 import sql
from openai import AzureOpenAI 
import pandas as pd
import age

conn = psycopg2.connect(db_uri)

gpt_embedding_client = AzureOpenAI(
    azure_endpoint=EMBEDDINGS_ENDPOINT,
    api_key=EMBEDDINGS_KEY,
    api_version="2025-02-01-preview",
)

gpt_4o_client = AzureOpenAI(  
    azure_endpoint=GPT_4O_ENDPOINT,  
    api_key=GPT_4O_KEY,  
    api_version="2024-08-01-preview",
)

gpt_4o_mini_client = AzureOpenAI(
    azure_endpoint=GPT_4O_MINI_ENDPOINT,  
    api_key=GPT_4O_MINI_KEY,  
    api_version="2024-08-01-preview",
)

# %%
from enum import Enum
from pydantic import BaseModel, ValidationError, conlist, Field
from typing import List
import jinja2

class SubQuestions(BaseModel):
    questions: List[str] = Field(description="List of specific sub-questions derived from the main user query, preferably 3 or more")

class TraitEnum(Enum):
    MOVIE = "Movie"
    GENRE = "Genre"
    CHARACTER = "Character"
    SETTING = "Setting"
    THEME = "Theme"
    SERIES = "Series"

class SearchTypeEnum(Enum):
    SEMANTIC = "Semantic"
    KEYWORD = "Keyword"
    GRAPH = "Graph"

class QueryStep(BaseModel):
    query: str = Field(
        description="For KEYWORD search, include ONLY raw essential terms (names, places, identifiers) without any additional words. For SEMANTIC search, rewrite query to better match knowledge base."
    )
    trait: List[TraitEnum] = Field(
        description="List of traits being targeted in this query (Movie, Character, etc.)"
    )
    search_type: SearchTypeEnum = Field(
        description="Type of search to perform: KEYWORD for exact minimal term matching, SEMANTIC for meaning-based search, GRAPH for relationship queries"
    )

class QueryStrategy(BaseModel):
    steps: List[QueryStep] = Field(
        description="Ordered sequence of search steps, where later steps build on results of earlier steps"
    )
    id: str = Field(
        description="Unique random identifier for this strategy"
    )
    message_to_user: str = Field(
        description="Message to be displayed to the user, explaining the purpose of this query. Include type of each query step and its relation to other steps. Wording should be about what you are doing, example: 'Searching Movie using keyword search for Star Wars followed by graph query to get related genres and semantic movie search among results."
    )

class QueryStrategies(BaseModel):
    strategies: List[QueryStrategy] = Field(
        description="List of strategies, each containing a series of steps to be executed sequentially. Each strategy is a sequence of steps, where each step depends on the results of previous steps."
    )

def get_subquestions(llm_client: AzureOpenAI, question: str) -> SubQuestions:
    with open("./prompts/subquestions.jinja2", 'r') as f:
        system_prompt_template = jinja2.Template(f.read())
    system_prompt = system_prompt_template.render()
    messages = [
        {"role": "system", "content": system_prompt}, 
        {"role": "user", "content": question},
        ]
    completion = llm_client.beta.chat.completions.parse(  
        model="gpt-4o",
        messages=messages,
        response_format=SubQuestions,
        max_tokens=1000,  
        temperature=0.7,
    )
    return SubQuestions.model_validate_json(completion.choices[0].message.content)

def prepare_strategies(llm_client: AzureOpenAI, question: str) -> QueryStrategies:
    with open("./prompts/query_strategy.jinja2", 'r') as f:
        system_prompt_template = jinja2.Template(f.read())
    system_prompt = system_prompt_template.render()
    messages = [
        {"role": "system", "content": system_prompt}, 
        {"role": "user", "content": question},
        ]
    completion = llm_client.beta.chat.completions.parse(  
        model="gpt-4o",
        messages=messages,
        response_format=QueryStrategies,
        max_tokens=1000,  
        temperature=0.7,
    )
    return QueryStrategies.model_validate_json(completion.choices[0].message.content)

def batch_prepare_strategies(llm_client: AzureOpenAI, questions: SubQuestions) -> QueryStrategies:
    all_strategies = []
    for question in questions.questions:
        strategies = prepare_strategies(llm_client, question)
        all_strategies.extend(strategies.strategies)

    return QueryStrategies(strategies=all_strategies)

# %%
for question in questions:
    sub_questions = get_subquestions(gpt_4o_client, question)
    strategies = batch_prepare_strategies(gpt_4o_client, sub_questions)
    print(f"\n\n****************************\nStrategies for question: {question}")
    print(strategies.model_dump_json(indent=2))
# Out:
# ****************************
# Strategies for question: What movies are about Abby?
# {
#   "strategies": [
#     {
#       "steps": [
#         {
#           "query": "Abby",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "b307f750-2eec-4e4c-9733-d5dbb9c5b9e6",
#       "message_to_user": "Performing a keyword search for the character name 'Abby' to locate relevant movies."
#     },
#     {
#       "steps": [
#         {
#           "query": "movies featuring a character named Abby",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "65e1cbec-93ed-4596-a6f4-5c2b25d4b4c1",
#       "message_to_user": "Searching semantically for movies that feature a character named Abby to find related results."
#     },
#     {
#       "steps": [
#         {
#           "query": "Abby",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "f2ae73fc-9c0d-4b61-9c9b-8a5f1c0d1372",
#       "message_to_user": "Performing a keyword search for characters named 'Abby' to identify movies where she appears."
#     },
#     {
#       "steps": [
#         {
#           "query": "movies with Abby as the main character",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "b6f0d6e2-3c24-4c81-8c1e-3e8a2b9c8c6d",
#       "message_to_user": "Using semantic search to find movies where 'Abby' is the main character."
#     },
#     {
#       "steps": [
#         {
#           "query": "Abby",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "1c0d3f18-9b1f-4b62-8f8f-4c9d7e4edceb",
#       "message_to_user": "Searching for characters named Abby using a keyword search to identify related movies."
#     },
#     {
#       "steps": [
#         {
#           "query": "Abby",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "Prominent",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "b1f2e8b8-8a8b-4cb9-9f34-6d9e7b8c9f80",
#       "message_to_user": "Starting with a keyword search for characters named Abby, followed by a semantic search to refine results for prominence."
#     }
#   ]
# }
#
#
# ****************************
# Strategies for question: I have seen all Star Wars movies and would like tips for something similar I can watch next.
# {
#   "strategies": [
#     {
#       "steps": [
#         {
#           "query": "Star Wars",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "science fiction",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Semantic"
#         },
#         {
#           "query": "",
#           "trait": [
#             "Series"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "1c2c3d8d-213e-4c81-8152-abc3e3feed4f",
#       "message_to_user": "Searching Movie using keyword search for Star Wars to find related films, followed by finding science fiction Genre, and finally graph query to identify Series matching criteria."
#     },
#     {
#       "steps": [
#         {
#           "query": "science fiction movie series",
#           "trait": [
#             "Series"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "2f7f9eaa-89c6-4d11-a6f5-1fd20a2dcb82",
#       "message_to_user": "Performing semantic search directly for science fiction movie series to identify entries similar to Star Wars."
#     },
#     {
#       "steps": [
#         {
#           "query": "Star Wars",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "themes",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Graph"
#         },
#         {
#           "query": "similar TV series",
#           "trait": [
#             "Series"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "1b9a3e2f-9fcb-4e8c-b7c4-5b0e1d111e5a",
#       "message_to_user": "Searching Movie using keyword search for Star Wars, followed by a graph query to retrieve themes, and finally using semantic search to find TV series with similar themes."
#     },
#     {
#       "steps": [
#         {
#           "query": "Star Wars",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Semantic"
#         },
#         {
#           "query": "TV series",
#           "trait": [
#             "Series"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "c2d5a9e3-3d65-4022-bc1d-85cf4ec3da9f",
#       "message_to_user": "Starting with semantic search for themes related to Star Wars, followed by semantic search for TV series matching those themes."
#     },
#     {
#       "steps": [
#         {
#           "query": "Star Wars",
#           "trait": [
#             "Movie",
#             "Series"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "animated",
#           "trait": [
#             "Movie",
#             "Series"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "1b1f49c9-3340-4f2a-bc8c-4b63369e8274",
#       "message_to_user": "We'll use a keyword search to find references to Star Wars within movies or series and then perform a semantic search for animated productions within the results."
#     },
#     {
#       "steps": [
#         {
#           "query": "Star Wars animated",
#           "trait": [
#             "Movie",
#             "Series"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "c8a5be2e-32a8-4f2b-9ad8-0a6c2e2dd7a3",
#       "message_to_user": "We'll perform a semantic search for animated movies or shows reminiscent of the Star Wars saga."
#     },
#     {
#       "steps": [
#         {
#           "query": "Star Wars",
#           "trait": [
#             "Series"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "epic storytelling",
#           "trait": [
#             "Series"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "1b3b4e2f-4a72-49b3-9e23-98c3b9c3a3d4",
#       "message_to_user": "Performing a keyword search for Star Wars in Series trait to identify the franchise, followed by semantic search for epic storytelling among similar series."
#     },
#     {
#       "steps": [
#         {
#           "query": "Star Wars",
#           "trait": [
#             "Series"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "epic storytelling",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "2c4d5f6e-5b81-4c74-8dbe-45d5c9d5e4f1",
#       "message_to_user": "Searching for Star Wars in Series to identify the franchise, then semantic search for epic storytelling in themes related to identified series."
#     },
#     {
#       "steps": [
#         {
#           "query": "space opera Star Wars",
#           "trait": [
#             "Genre",
#             "Theme"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "b12f1d7a-8b36-4f9f-ae8b-9c6f0f7d7d42",
#       "message_to_user": "Performing semantic search to identify movies or shows with space opera elements similar to Star Wars."
#     },
#     {
#       "steps": [
#         {
#           "query": "Star Wars",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "space opera",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "6c3a2b4c-0f44-42a1-95e3-78f1a67d8b3e",
#       "message_to_user": "First using keyword search to find Star Wars in movies, then exploring related genres with graph search to identify space opera themes."
#     }
#   ]
# }
#
#
# ****************************
# Strategies for question: What is the most common genre of the movies where one of key figures is called Mark?
# {
#   "strategies": [
#     {
#       "steps": [
#         {
#           "query": "Mark",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "885c24c2-9a0d-4943-aba8-6c94e04e1b14",
#       "message_to_user": "Searching for characters named Mark using keyword search to identify relevant movies."
#     },
#     {
#       "steps": [
#         {
#           "query": "movies featuring a character named Mark",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "fb7d7c45-2e27-4d72-8c7f-6a38dcd5e0a2",
#       "message_to_user": "Using semantic search to find movies with a key character named Mark."
#     },
#     {
#       "steps": [
#         {
#           "query": "Mark",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "common genres",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "b3b8f428-0a9f-4d7b-9b04-7b06f9873f35",
#       "message_to_user": "Starting with a keyword search for characters named 'Mark' to identify relevant movies, followed by a graph search to find common genres among these movies."
#     },
#     {
#       "steps": [
#         {
#           "query": "movies with character named Mark",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         },
#         {
#           "query": "common genres",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "985c1c3c-78ff-4c7e-9b2b-0b5e8cb3a9fa",
#       "message_to_user": "Using a semantic search to find movies featuring a character named 'Mark', and then performing a graph search to identify common genres among these movies."
#     },
#     {
#       "steps": [
#         {
#           "query": "Mark",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "Genre",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "b1f4d6c1-8f7a-4816-a8d5-2c8da6a4d45a",
#       "message_to_user": "Starting with a keyword search for the character Mark, then using graph search to explore associated genres."
#     },
#     {
#       "steps": [
#         {
#           "query": "movies featuring a character named Mark and their associated genres",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "7c769d78-e08d-4b10-96d5-8f3e1d3fc4d3",
#       "message_to_user": "Performing a semantic search to find movies with a character named Mark and analyze their genres."
#     }
#   ]
# }
#
#
# ****************************
# Strategies for question: Are there any movies where Prague takes major role and present city as mysterious and ancient?
# {
#   "strategies": [
#     {
#       "steps": [
#         {
#           "query": "Prague",
#           "trait": [
#             "Setting"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "b8a9a0f5-0f4d-4df2-8952-3c53b2c9eaf2",
#       "message_to_user": "Searching Setting using keyword search for Prague to identify movies featuring this location prominently."
#     },
#     {
#       "steps": [
#         {
#           "query": "movies featuring Prague as a major setting",
#           "trait": [
#             "Setting"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "d09af749-4b85-48f6-81eb-9c9d92d01d7e",
#       "message_to_user": "Performing semantic search in Setting to find movies prominently featuring Prague."
#     },
#     {
#       "steps": [
#         {
#           "query": "Prague",
#           "trait": [
#             "Setting"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "mysterious ancient",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "strategy1",
#       "message_to_user": "Searching Setting using keyword search for Prague followed by semantic search in Theme to find related movies."
#     },
#     {
#       "steps": [
#         {
#           "query": "Prague",
#           "trait": [
#             "Setting"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "mysterious and ancient city",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "strategy2",
#       "message_to_user": "Searching Setting using keyword search for Prague followed by semantic search in Movie to find films with the described characteristics."
#     },
#     {
#       "steps": [
#         {
#           "query": "Prague architecture ambiance",
#           "trait": [
#             "Setting",
#             "Theme"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "71f61d4b-cb96-4d8d-9e5c-5a776a67d7c9",
#       "message_to_user": "Performing a keyword search targeting settings and themes with terms 'Prague architecture ambiance' to identify related films."
#     },
#     {
#       "steps": [
#         {
#           "query": "films highlighting Prague's historical architecture and ambiance",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "eebedb15-2a5e-4c36-8e6d-5b3b177c9b73",
#       "message_to_user": "Conducting a semantic search in the Movie trait to find films that match the description of emphasizing Prague's historical architecture and ambiance."
#     }
#   ]
# }
#
#
# ****************************
# Strategies for question: When movies about drugs are concerned, is it usually rather serious or funny?
# {
#   "strategies": [
#     {
#       "steps": [
#         {
#           "query": "movies about drugs",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "cf08cf2b-6fbc-4b0f-9b16-5e3f3de6bdf6",
#       "message_to_user": "Searching Themes using semantic search for movies about drugs to identify common motifs."
#     },
#     {
#       "steps": [
#         {
#           "query": "movies about drugs",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         },
#         {
#           "query": "themes",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "8c8e4a5d-cc18-4dbe-a3d0-0a7a2fc7b4e3",
#       "message_to_user": "First searching Movies using semantic search for movies about drugs, then performing graph search to identify related Themes."
#     },
#     {
#       "steps": [
#         {
#           "query": "movies about drugs",
#           "trait": [
#             "Theme",
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "b30b8b53-8c0c-4e56-a5d7-f9f3bda4e1b0",
#       "message_to_user": "Conducting a semantic search to explore movies with themes about drugs and analyze their tone."
#     },
#     {
#       "steps": [
#         {
#           "query": "drugs",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "serious comedic",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "2c35b9e4-5a09-4c2c-9f71-4b9d16d4c609",
#       "message_to_user": "First performing a keyword search for the drug-related theme, then analyzing the tone of the associated movies using semantic search."
#     },
#     {
#       "steps": [
#         {
#           "query": "serious movies about drugs",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "d943b9d5-5e67-4c6d-9a4d-d98c30090dde",
#       "message_to_user": "Searching for movies using semantic search for serious topics related to drugs."
#     },
#     {
#       "steps": [
#         {
#           "query": "drugs",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "serious",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "c8e2a1c9-1a7d-4892-bc4e-7f543d3c1ff4",
#       "message_to_user": "Starting with themes using keyword search for drugs, followed by semantic search for serious movies within those themes."
#     },
#     {
#       "steps": [
#         {
#           "query": "comedic movies about drugs",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "b4d3ee2e-455b-4a8b-9b6a-b798a6a3e201",
#       "message_to_user": "Searching for comedic movies about drugs using semantic search to find relevant examples."
#     },
#     {
#       "steps": [
#         {
#           "query": "comedy",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "drugs",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "b9c1d0a9-0d41-4f2a-9e34-2e1b681d7c29",
#       "message_to_user": "Performing keyword searches to identify comedy movies with themes related to drugs."
#     },
#     {
#       "steps": [
#         {
#           "query": "movies about drugs",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "d8f9c1c4-3a21-4d7c-999b-9cfa1d0e8eaf",
#       "message_to_user": "Performing a semantic search on movies to find those dealing with drug-related issues."
#     },
#     {
#       "steps": [
#         {
#           "query": "drug-related issues",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Semantic"
#         },
#         {
#           "query": "movies about drugs",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "b5a2db8b-1e0f-4cbb-9cbf-7f888aaba9f2",
#       "message_to_user": "Searching for themes related to drug-related issues and then looking for movies that align with those themes using graph search."
#     }
#   ]
# }
#
#
# ****************************
# Strategies for question: What are some movies featuring a strong female lead that also involve adventure?
# {
#   "strategies": [
#     {
#       "steps": [
#         {
#           "query": "movies with strong female leads",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "1c2d5f9b-8b74-4d73-ae76-79dfa6b3c0aa",
#       "message_to_user": "Performing a semantic search to find movies that feature strong female leads."
#     },
#     {
#       "steps": [
#         {
#           "query": "strong female leads",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "related movies",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "6e2d7a5f-9f8a-486d-9f23-4b4b8e9c3bda",
#       "message_to_user": "Starting with a keyword search for themes related to strong female leads, then retrieving movies associated with those themes using a graph search."
#     },
#     {
#       "steps": [
#         {
#           "query": "female protagonist adventure",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "6a4d2b32-5b10-496d-940c-6bdf8c9a218d",
#       "message_to_user": "Performing semantic search in the Movie trait to find films that fit the description of female protagonists in adventure settings."
#     },
#     {
#       "steps": [
#         {
#           "query": "adventure",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "181e2e9d-3f62-465f-9c80-3c9f2b4e4c69",
#       "message_to_user": "First, we perform a keyword search to identify the 'Adventure' genre, followed by a graph search to find movies within this genre."
#     },
#     {
#       "steps": [
#         {
#           "query": "adventure female",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "strategy_1",
#       "message_to_user": "Conducting a keyword search for adventure films with female characters."
#     },
#     {
#       "steps": [
#         {
#           "query": "notable adventure films with prominent female characters",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "strategy_2",
#       "message_to_user": "Performing a semantic search to match notable adventure films featuring prominent female characters."
#     },
#     {
#       "steps": [
#         {
#           "query": "adventurous themes strong female lead",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "7e421d0a-0bfc-4baf-8c7c-86d2c657b8d5",
#       "message_to_user": "Conducting a semantic search for movies with adventurous themes and strong female leads to directly match your query."
#     },
#     {
#       "steps": [
#         {
#           "query": "adventurous themes",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "strong female lead",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "adventurous themes strong female lead",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Graph"
#         }
#       ],
#       "id": "d9a4f8b9-2b6d-4a6a-bb3b-1c3b3c9c58ab",
#       "message_to_user": "Performing keyword searches for themes and characters to build a graph query, followed by retrieving movies based on these traits."
#     },
#     {
#       "steps": [
#         {
#           "query": "female leads action adventure",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "1d0481ff-1d6f-4b2f-9f6b-2f12f7cfdc2f",
#       "message_to_user": "Searching for movies with female leads that combine action and adventure elements using a semantic search."
#     },
#     {
#       "steps": [
#         {
#           "query": "action adventure",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "female leads",
#           "trait": [
#             "Character"
#           ],
#           "search_type": "Semantic"
#         },
#         {
#           "query": "action adventure",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "982f707b-2f4b-4566-bb6d-7e5f5c9fdc3b",
#       "message_to_user": "Starting with keyword search for genres related to action and adventure, followed by a semantic search for female leads in characters, and concluding with semantic search for movies combining these elements."
#     }
#   ]
# }
#
#
# ****************************
# Strategies for question: Which Western films feature outlaws riding to their doom in the American Southwest?
# {
#   "strategies": [
#     {
#       "steps": [
#         {
#           "query": "Western American Southwest outlaws",
#           "trait": [
#             "Setting",
#             "Genre",
#             "Theme"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "0e2b7206-0d69-46da-bc5a-3d2c9d3a8b4f",
#       "message_to_user": "Performing a keyword search for Western films set in the American Southwest featuring outlaws."
#     },
#     {
#       "steps": [
#         {
#           "query": "Western films set in the American Southwest featuring outlaws",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "36d759dc-9d4e-4a6d-9d4f-02e2b99f9e8f",
#       "message_to_user": "Performing a semantic search to find Western films matching the description of being set in the Southwest and featuring outlaws."
#     },
#     {
#       "steps": [
#         {
#           "query": "Western outlaws demise",
#           "trait": [
#             "Movie",
#             "Theme"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "8cf2e9a5-f73c-4b6c-86d5-1b9e6a1b9f26",
#       "message_to_user": "Using semantic search to find Western movies that involve themes of outlaws meeting their demise."
#     },
#     {
#       "steps": [
#         {
#           "query": "Western",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "outlaws demise",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "5d5897c2-33e8-4a4b-895d-2bdde46e7a3e",
#       "message_to_user": "Starting with keyword search for Western genre, followed by semantic search for themes related to outlaws meeting their demise."
#     },
#     {
#       "steps": [
#         {
#           "query": "Western outlaws desert doom",
#           "trait": [
#             "Movie"
#           ],
#           "search_type": "Semantic"
#         }
#       ],
#       "id": "1e0c0a57-8f74-4f73-8f49-0c6c7586e8fa",
#       "message_to_user": "Conducting a semantic search for Western movies that depict outlaws riding towards their doom in desert or Southwest landscapes."
#     },
#     {
#       "steps": [
#         {
#           "query": "Western",
#           "trait": [
#             "Genre"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "desert",
#           "trait": [
#             "Setting"
#           ],
#           "search_type": "Keyword"
#         },
#         {
#           "query": "doom",
#           "trait": [
#             "Theme"
#           ],
#           "search_type": "Keyword"
#         }
#       ],
#       "id": "2a5d3bdf-d3b3-4b30-bb51-d68f6e9b7e31",
#       "message_to_user": "Searching for movies with Western genre, desert setting, and themes of doom using keyword searches."
#     }
#   ]
# }
